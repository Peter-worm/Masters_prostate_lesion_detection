# %%
text = """
After Epoch 1:
Current allocated memory: 24.82 MB
models/retina_unet.py:226: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
  keep_arr = torch.cat(((keep_ix // fg_probs.shape[1]).unsqueeze(1), (keep_ix % fg_probs.shape[1]).unsqueeze(1)), 1)
tr. batch 120/120 (ep. 1) fw 0.42s / bw 0.13 s / total 0.55 s || loss: 2.32, class: 1.55, bbox: 0.30, seg dice: 0.895, seg ce: 0.031, mean pix. pr.: 0.00369
evaluating in mode train
evaluating with match_iou: 1e-05
generating training example plot.
starting validation in mode val_sampling.
models/retina_unet.py:226: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
  keep_arr = torch.cat(((keep_ix // fg_probs.shape[1]).unsqueeze(1), (keep_ix % fg_probs.shape[1]).unsqueeze(1)), 1)
evaluating in mode val_sampling
evaluating with match_iou: 1e-05
saving current epoch 1 at rank [[0]]
trained epoch 1: took 1m:39s (1m:18s train / 0m:20s val)
models/retina_unet.py:226: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
  keep_arr = torch.cat(((keep_ix // fg_probs.shape[1]).unsqueeze(1), (keep_ix % fg_probs.shape[1]).unsqueeze(1)), 1)
generating validation-sampling example plot.
starting training epoch 2
After Epoch 2:
Current allocated memory: 670.00 MB
tr. batch 120/120 (ep. 2) fw 0.44s / bw 0.13 s / total 0.57 s || loss: 1.40, class: 0.60, bbox: 0.43, seg dice: 0.720, seg ce: 0.033, mean pix. pr.: 0.01157
evaluating in mode train
evaluating with match_iou: 1e-05
generating training example plot.
starting validation in mode val_sampling.
models/retina_unet.py:226: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
  keep_arr = torch.cat(((keep_ix // fg_probs.shape[1]).unsqueeze(1), (keep_ix % fg_probs.shape[1]).unsqueeze(1)), 1)
evaluating in mode val_sampling
evaluating with match_iou: 1e-05
saving current epoch 2 at rank [[0]]
trained epoch 2: took 1m:24s (1m:05s train / 0m:19s val)
models/retina_unet.py:226: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
  keep_arr = torch.cat(((keep_ix // fg_probs.shape[1]).unsqueeze(1), (keep_ix % fg_probs.shape[1]).unsqueeze(1)), 1)
generating validation-sampling example plot.
starting training epoch 3
After Epoch 3:
Current allocated memory: 1257.40 MB
tr. batch 120/120 (ep. 3) fw 0.40s / bw 0.13 s / total 0.53 s || loss: 1.48, class: 0.25, bbox: 0.70, seg dice: 0.987, seg ce: 0.080, mean pix. pr.: 0.01290
evaluating in mode train
evaluating with match_iou: 1e-05
generating training example plot.
starting validation in mode val_sampling.
models/retina_unet.py:226: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
  keep_arr = torch.cat(((keep_ix // fg_probs.shape[1]).unsqueeze(1), (keep_ix % fg_probs.shape[1]).unsqueeze(1)), 1)
evaluating in mode val_sampling
evaluating with match_iou: 1e-05
saving current epoch 3 at rank [[0]]
trained epoch 3: took 1m:24s (1m:06s train / 0m:18s val)
models/retina_unet.py:226: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
  keep_arr = torch.cat(((keep_ix // fg_probs.shape[1]).unsqueeze(1), (keep_ix % fg_probs.shape[1]).unsqueeze(1)), 1)
generating validation-sampling example plot.
starting training epoch 4
After Epoch 4:
Current allocated memory: 1830.09 MB
tr. batch 120/120 (ep. 4) fw 0.36s / bw 0.13 s / total 0.49 s || loss: 2.13, class: 0.10, bbox: 1.64, seg dice: 0.742, seg ce: 0.033, mean pix. pr.: 0.00535
evaluating in mode train
evaluating with match_iou: 1e-05
generating training example plot.
starting validation in mode val_sampling.
models/retina_unet.py:226: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
  keep_arr = torch.cat(((keep_ix // fg_probs.shape[1]).unsqueeze(1), (keep_ix % fg_probs.shape[1]).unsqueeze(1)), 1)
evaluating in mode val_sampling
evaluating with match_iou: 1e-05
saving current epoch 4 at rank [[0]]
trained epoch 4: took 1m:24s (1m:06s train / 0m:17s val)
models/retina_unet.py:226: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
  keep_arr = torch.cat(((keep_ix // fg_probs.shape[1]).unsqueeze(1), (keep_ix % fg_probs.shape[1]).unsqueeze(1)), 1)
generating validation-sampling example plot.
starting training epoch 5
After Epoch 5:
Current allocated memory: 2402.79 MB
tr. batch 120/120 (ep. 5) fw 0.37s / bw 0.13 s / total 0.51 s || loss: 1.26, class: 0.21, bbox: 0.67, seg dice: 0.722, seg ce: 0.061, mean pix. pr.: 0.01266
evaluating in mode train
evaluating with match_iou: 1e-05
generating training example plot.
starting validation in mode val_sampling.
models/retina_unet.py:226: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
  keep_arr = torch.cat(((keep_ix // fg_probs.shape[1]).unsqueeze(1), (keep_ix % fg_probs.shape[1]).unsqueeze(1)), 1)
evaluating in mode val_sampling
evaluating with match_iou: 1e-05
saving current epoch 5 at rank [[0]]
trained epoch 5: took 1m:23s (1m:05s train / 0m:17s val)
models/retina_unet.py:226: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
  keep_arr = torch.cat(((keep_ix // fg_probs.shape[1]).unsqueeze(1), (keep_ix % fg_probs.shape[1]).unsqueeze(1)), 1)
generating validation-sampling example plot.
starting training epoch 6
After Epoch 6:
Current allocated memory: 2986.86 MB
tr. batch 120/120 (ep. 6) fw 0.36s / bw 0.15 s / total 0.51 s || loss: 2.84, class: 1.45, bbox: 1.04, seg dice: 0.609, seg ce: 0.084, mean pix. pr.: 0.01840
evaluating in mode train
evaluating with match_iou: 1e-05
generating training example plot.
starting validation in mode val_sampling.
models/retina_unet.py:226: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
  keep_arr = torch.cat(((keep_ix // fg_probs.shape[1]).unsqueeze(1), (keep_ix % fg_probs.shape[1]).unsqueeze(1)), 1)
evaluating in mode val_sampling
evaluating with match_iou: 1e-05
saving current epoch 6 at rank [[0]]
deleting epoch 1 at rank [[5]]
trained epoch 6: took 1m:23s (1m:04s train / 0m:18s val)
models/retina_unet.py:226: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
  keep_arr = torch.cat(((keep_ix // fg_probs.shape[1]).unsqueeze(1), (keep_ix % fg_probs.shape[1]).unsqueeze(1)), 1)
generating validation-sampling example plot.
starting training epoch 7
After Epoch 7:
Current allocated memory: 3560.08 MB
tr. batch 120/120 (ep. 7) fw 0.36s / bw 0.13 s / total 0.48 s || loss: 1.80, class: 0.64, bbox: 0.85, seg dice: 0.564, seg ce: 0.043, mean pix. pr.: 0.00284
evaluating in mode train
evaluating with match_iou: 1e-05
generating training example plot.
starting validation in mode val_sampling.
models/retina_unet.py:226: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
  keep_arr = torch.cat(((keep_ix // fg_probs.shape[1]).unsqueeze(1), (keep_ix % fg_probs.shape[1]).unsqueeze(1)), 1)
evaluating in mode val_sampling
evaluating with match_iou: 1e-05
saving current epoch 7 at rank [[0]]
deleting epoch 2 at rank [[5]]
trained epoch 7: took 1m:25s (1m:05s train / 0m:20s val)
models/retina_unet.py:226: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
  keep_arr = torch.cat(((keep_ix // fg_probs.shape[1]).unsqueeze(1), (keep_ix % fg_probs.shape[1]).unsqueeze(1)), 1)
generating validation-sampling example plot.
starting training epoch 8
After Epoch 8:
Current allocated memory: 4133.74 MB
tr. batch 120/120 (ep. 8) fw 0.42s / bw 0.14 s / total 0.56 s || loss: 0.86, class: 0.09, bbox: 0.32, seg dice: 0.846, seg ce: 0.056, mean pix. pr.: 0.00878
evaluating in mode train
evaluating with match_iou: 1e-05
generating training example plot.
starting validation in mode val_sampling.
models/retina_unet.py:226: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
  keep_arr = torch.cat(((keep_ix // fg_probs.shape[1]).unsqueeze(1), (keep_ix % fg_probs.shape[1]).unsqueeze(1)), 1)
evaluating in mode val_sampling
evaluating with match_iou: 1e-05
saving current epoch 8 at rank [[0]]
deleting epoch 3 at rank [[5]]
trained epoch 8: took 1m:25s (1m:06s train / 0m:19s val)
models/retina_unet.py:226: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
  keep_arr = torch.cat(((keep_ix // fg_probs.shape[1]).unsqueeze(1), (keep_ix % fg_probs.shape[1]).unsqueeze(1)), 1)
generating validation-sampling example plot.
starting training epoch 9
After Epoch 9:
Current allocated memory: 4707.71 MB
tr. batch 120/120 (ep. 9) fw 0.41s / bw 0.13 s / total 0.54 s || loss: 1.75, class: 0.86, bbox: 0.64, seg dice: 0.421, seg ce: 0.077, mean pix. pr.: 0.00929
evaluating in mode train
evaluating with match_iou: 1e-05
generating training example plot.
starting validation in mode val_sampling.
models/retina_unet.py:226: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
  keep_arr = torch.cat(((keep_ix // fg_probs.shape[1]).unsqueeze(1), (keep_ix % fg_probs.shape[1]).unsqueeze(1)), 1)
evaluating in mode val_sampling
evaluating with match_iou: 1e-05
saving current epoch 9 at rank [[0]]
deleting epoch 4 at rank [[5]]
trained epoch 9: took 1m:25s (1m:06s train / 0m:19s val)
models/retina_unet.py:226: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
  keep_arr = torch.cat(((keep_ix // fg_probs.shape[1]).unsqueeze(1), (keep_ix % fg_probs.shape[1]).unsqueeze(1)), 1)
generating validation-sampling example plot.
starting training epoch 10
After Epoch 10:
Current allocated memory: 5281.68 MB
"""

# %%
import re

# Find all numbers that appear after "ab:" and before "Mb"
numbers = re.findall(r'Current allocated memory:\s*([\d.]+)\s* MB', text)

# Convert them to integers
numbers = [float(num) for num in numbers]

diffs = [numbers[i+1] - numbers[i] for i in range(len(numbers) - 1)]

print("Numbers:", numbers)
print("Differences:", diffs)
# Out:
# Numbers: [24.82, 670.0, 1257.4, 1830.09, 2402.79, 2986.86, 3560.08, 4133.74, 4707.71, 5281.68]
# Differences: [645.18, 587.4000000000001, 572.6899999999998, 572.7, 584.0700000000002, 573.2199999999998, 573.6599999999999, 573.9700000000003, 573.9700000000003]
