# %%
import matplotlib.pyplot as plt
import numpy as np
from core.file_manager import preprocess_file_manager
from core.stat_calc import find_periods

# %%
orginal_data_folder =  '/home/robakp/Exeriments1/prostate_lesion_detection/rjozwiak-MGR_dataset_correct/MGR_dataset_correct'

channels = {
    'adc' : 'adc',
    'anatomy' : 'anatomy',
    'dwi' : 'dwi',
    't2' : 't2'
}

target = 'lesion'

file_extention = '.nii.gz'

preprocessed_steps = [
    'raw',
    'filling_anatomy_gaps'
]

# %%
file_manager = preprocess_file_manager('/home/robakp/Exeriments1/prostate_lesion_detection/juzwiak_preprocessed',preprocessed_steps,channels)
patients = file_manager.get_file_names()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/Exeriments1/prostate_lesion_detection/venv_prostate_try_2/lib/python3.7/site-packages/IPython/core/async_helpers.py in _pseudo_sync_runner(coro)
#      76     """
#      77     try:
# ---> 78         coro.send(None)
#      79     except StopIteration as exc:
#      80         return exc.value
#
# ~/Exeriments1/prostate_lesion_detection/venv_prostate_try_2/lib/python3.7/site-packages/IPython/core/interactiveshell.py in run_cell_async(self, raw_cell, store_history, silent, shell_futures, transformed_cell, preprocessing_exc_tuple, cell_id)
#    3179         if store_history:
#    3180             self.history_manager.store_inputs(self.execution_count,
# -> 3181                                               cell, raw_cell)
#    3182         if not silent:
#    3183             self.logger.log(cell, raw_cell)
#
# ~/Exeriments1/prostate_lesion_detection/venv_prostate_try_2/lib/python3.7/site-packages/IPython/core/history.py in store_inputs(self, line_num, source, source_raw)
#     717         self.input_hist_raw.append(source_raw)
#     718
# --> 719         with self.db_input_cache_lock:
#     720             self.db_input_cache.append((line_num, source, source_raw))
#     721             # Trigger to flush cache and write to DB.
#
# KeyboardInterrupt:

# %% [markdown]
# check how big portions with prostate are

# %%
for patient in patients[:1]:
    print(patient)
    prostate = file_manager.load_file('raw',patient)['anatomy'] 
    valid_layers = np.any(prostate == 1, axis=(0, 1))
    print(valid_layers.shape)
# Out:
# 3322
# (41,)

# %%
true_indices = np.where(valid_layers)[0]
print(true_indices)
print(len(find_periods(true_indices)))
# Out:
# [15 16 17 18 19 20 22 23 24 25 26 27 28 29 30]
# 2

# %%
from core.anatomy_gap_fixer import find_gaps_in_anatomy

outliers,_ = find_gaps_in_anatomy(patients,file_manager)

for outlier in outliers:
    print(outlier)
    prostate = file_manager.load_file('raw',outlier)['anatomy'] 
    valid_layers = np.any(prostate == 1, axis=(0, 1))
    true_indices = np.where(valid_layers)[0]
    periods = find_periods(true_indices)
    print(len(periods))
    print(periods)
