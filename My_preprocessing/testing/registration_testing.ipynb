# %%
import nibabel as nib
from pathlib import Path
import pickle
import os
from tqdm import tqdm

# %%
data_folder =  '/home/robakp/Exeriments1/prostate_lesion_detection/rjozwiak-MGR_dataset_correct/MGR_dataset_correct'

channels = {
    'adc' : 'adc',
    'anatomy' : 'anatomy',
    'dwi' : 'dwi',
    't2' : 't2'
}

target = 'lesion'

file_extention = '.nii.gz'

preprocessed_steps = [
    'raw',
    'filling_anatomy_gaps'
]

# %%
print(t2.GetSize(), adc.GetSize())
print(t2.GetSpacing(), adc.GetSpacing())
print(t2.GetOrigin(), adc.GetOrigin())
print(t2.GetDirection(), adc.GetDirection())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_228829/1222656290.py in <module>
# ----> 1 print(t2.GetSize(), adc.GetSize())
#       2 print(t2.GetSpacing(), adc.GetSpacing())
#       3 print(t2.GetOrigin(), adc.GetOrigin())
#       4 print(t2.GetDirection(), adc.GetDirection())
#
# NameError: name 't2' is not defined
