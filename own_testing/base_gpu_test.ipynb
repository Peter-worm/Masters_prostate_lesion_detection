# %%
import sys
print(sys.executable)
# Out:
# /home/robakp/Exeriments1/prostate_lesion_detection/venv_prostate_try_2/bin/python

# %%
# !which python
# !which pip
# Out:
# /home/robakp/Exeriments1/prostate_lesion_detection/venv_prostate_try_2/bin/python
# /home/robakp/Exeriments1/prostate_lesion_detection/venv_prostate_try_2/bin/pip

# %%
# !{sys.executable} -m pip list
# Out:
# Package                Version
# ---------------------- ------------
# absl-py                2.3.1
# aiofiles               22.1.0
# aiosqlite              0.19.0
# anyio                  3.7.1
# argon2-cffi            23.1.0
# argon2-cffi-bindings   21.2.0
# arrow                  1.2.3
# attrs                  24.2.0
# Babel                  2.14.0
# backcall               0.2.0
# batchgenerators        0.20.1
# beautifulsoup4         4.14.2
# bleach                 6.0.0
# cached-property        1.5.2
# cachetools             4.2.4
# certifi                2025.8.3
# cffi                   1.15.1
# charset-normalizer     3.4.3
# comm                   0.1.4
# cycler                 0.11.0
# debugpy                1.7.0
# decorator              5.1.1
# defusedxml             0.7.1
# entrypoints            0.4
# exceptiongroup         1.3.0
# fastjsonschema         2.21.2
# fonttools              4.38.0
# fqdn                   1.5.1
# future                 1.0.0
# google-auth            1.35.0
# google-auth-oauthlib   0.4.6
# grpcio                 1.48.2
# idna                   3.10
# imageio                2.5.0
# importlib-metadata     6.7.0
# importlib-resources    5.12.0
# ipykernel              6.16.2
# ipython                7.34.0
# ipython-genutils       0.2.0
# ipywidgets             8.1.7
# isoduration            20.11.0
# jedi                   0.19.2
# Jinja2                 3.1.6
# joblib                 1.3.2
# json5                  0.9.16
# jsonpointer            3.0.0
# jsonschema             4.17.3
# jupyter                1.1.1
# jupyter_client         7.4.9
# jupyter-console        6.6.3
# jupyter_core           4.12.0
# jupyter-events         0.6.3
# jupyter-server         1.24.0
# jupyter_server_fileid  0.9.3
# jupyter_server_ydoc    0.8.0
# jupyter-ydoc           0.2.5
# jupyterlab             3.6.8
# jupyterlab-pygments    0.2.2
# jupyterlab_server      2.24.0
# jupyterlab_widgets     3.0.15
# kiwisolver             1.4.5
# linecache2             1.0.0
# Markdown               3.9
# MarkupSafe             2.1.5
# matplotlib             3.5.3
# matplotlib-inline      0.1.6
# mistune                3.0.2
# nbclassic              1.2.0
# nbclient               0.7.4
# nbconvert              7.6.0
# nbformat               5.8.0
# nest-asyncio           1.6.0
# networkx               2.6.3
# ninja                  1.11.1.4
# nms-extension          0.0.0
# notebook               6.5.7
# notebook_shim          0.2.4
# numpy                  1.21.6
# oauthlib               3.3.1
# packaging              24.0
# pandas                 0.25.3
# pandocfilters          1.5.1
# parso                  0.8.5
# pexpect                4.9.0
# pickleshare            0.7.5
# Pillow                 7.0.0
# pip                    24.0
# pkgutil_resolve_name   1.3.10
# prometheus-client      0.17.1
# prompt_toolkit         3.0.48
# protobuf               6.32.1
# psutil                 7.1.0
# ptyprocess             0.7.0
# pyasn1                 0.6.1
# pyasn1_modules         0.4.2
# pycparser              2.21
# Pygments               2.17.2
# pyparsing              3.1.4
# pyrsistent             0.19.3
# python-dateutil        2.9.0.post0
# python-json-logger     3.0.1
# pytz                   2025.2
# PyWavelets             1.3.0
# PyYAML                 6.0.1
# pyzmq                  26.2.1
# requests               2.31.0
# requests-oauthlib      2.0.0
# rfc3339-validator      0.1.4
# rfc3986-validator      0.1.1
# rsa                    4.9.1
# scikit-image           0.18.3
# scikit-learn           1.0.2
# scipy                  1.7.3
# Send2Trash             1.8.3
# setuptools             68.0.0
# SimpleITK              1.2.4
# six                    1.17.0
# sniffio                1.3.1
# soupsieve              2.4.1
# tensorboard            2.2.0
# tensorboard-plugin-wit 1.8.1
# terminado              0.17.1
# threadpoolctl          3.1.0
# tifffile               2021.11.2
# tinycss2               1.2.1
# tomli                  2.0.1
# torch                  1.12.1+cu116
# torchaudio             0.12.1+cu116
# torchvision            0.13.1+cu116
# tornado                6.2
# tqdm                   4.67.1
# traceback2             1.4.0
# traitlets              5.9.0
# typing_extensions      4.7.1
# unittest2              1.1.0
# uri-template           1.3.0
# urllib3                2.0.7
# wcwidth                0.2.14
# webcolors              1.13
# webencodings           0.5.1
# websocket-client       1.6.1
# Werkzeug               3.1.3
# wheel                  0.46.1
# widgetsnbextension     4.0.14
# y-py                   0.6.2
# ypy-websocket          0.8.4
# zipp                   3.15.0

# %%
# !python -m pip list
# Out:
# Package                Version
# ---------------------- ------------
# absl-py                2.3.1
# aiofiles               22.1.0
# aiosqlite              0.19.0
# anyio                  3.7.1
# argon2-cffi            23.1.0
# argon2-cffi-bindings   21.2.0
# arrow                  1.2.3
# attrs                  24.2.0
# Babel                  2.14.0
# backcall               0.2.0
# batchgenerators        0.20.1
# beautifulsoup4         4.14.2
# bleach                 6.0.0
# cached-property        1.5.2
# cachetools             4.2.4
# certifi                2025.8.3
# cffi                   1.15.1
# charset-normalizer     3.4.3
# comm                   0.1.4
# cycler                 0.11.0
# debugpy                1.7.0
# decorator              5.1.1
# defusedxml             0.7.1
# entrypoints            0.4
# exceptiongroup         1.3.0
# fastjsonschema         2.21.2
# fonttools              4.38.0
# fqdn                   1.5.1
# future                 1.0.0
# google-auth            1.35.0
# google-auth-oauthlib   0.4.6
# grpcio                 1.48.2
# idna                   3.10
# imageio                2.5.0
# importlib-metadata     6.7.0
# importlib-resources    5.12.0
# ipykernel              6.16.2
# ipython                7.34.0
# ipython-genutils       0.2.0
# ipywidgets             8.1.7
# isoduration            20.11.0
# jedi                   0.19.2
# Jinja2                 3.1.6
# joblib                 1.3.2
# json5                  0.9.16
# jsonpointer            3.0.0
# jsonschema             4.17.3
# jupyter                1.1.1
# jupyter_client         7.4.9
# jupyter-console        6.6.3
# jupyter_core           4.12.0
# jupyter-events         0.6.3
# jupyter-server         1.24.0
# jupyter_server_fileid  0.9.3
# jupyter_server_ydoc    0.8.0
# jupyter-ydoc           0.2.5
# jupyterlab             3.6.8
# jupyterlab-pygments    0.2.2
# jupyterlab_server      2.24.0
# jupyterlab_widgets     3.0.15
# kiwisolver             1.4.5
# linecache2             1.0.0
# Markdown               3.9
# MarkupSafe             2.1.5
# matplotlib             3.5.3
# matplotlib-inline      0.1.6
# mistune                3.0.2
# nbclassic              1.2.0
# nbclient               0.7.4
# nbconvert              7.6.0
# nbformat               5.8.0
# nest-asyncio           1.6.0
# networkx               2.6.3
# ninja                  1.11.1.4
# nms-extension          0.0.0
# notebook               6.5.7
# notebook_shim          0.2.4
# numpy                  1.21.6
# oauthlib               3.3.1
# packaging              24.0
# pandas                 0.25.3
# pandocfilters          1.5.1
# parso                  0.8.5
# pexpect                4.9.0
# pickleshare            0.7.5
# Pillow                 7.0.0
# pip                    24.0
# pkgutil_resolve_name   1.3.10
# prometheus-client      0.17.1
# prompt_toolkit         3.0.48
# protobuf               6.32.1
# psutil                 7.1.0
# ptyprocess             0.7.0
# pyasn1                 0.6.1
# pyasn1_modules         0.4.2
# pycparser              2.21
# Pygments               2.17.2
# pyparsing              3.1.4
# pyrsistent             0.19.3
# python-dateutil        2.9.0.post0
# python-json-logger     3.0.1
# pytz                   2025.2
# PyWavelets             1.3.0
# PyYAML                 6.0.1
# pyzmq                  26.2.1
# requests               2.31.0
# requests-oauthlib      2.0.0
# rfc3339-validator      0.1.4
# rfc3986-validator      0.1.1
# rsa                    4.9.1
# scikit-image           0.18.3
# scikit-learn           1.0.2
# scipy                  1.7.3
# Send2Trash             1.8.3
# setuptools             68.0.0
# SimpleITK              1.2.4
# six                    1.17.0
# sniffio                1.3.1
# soupsieve              2.4.1
# tensorboard            2.2.0
# tensorboard-plugin-wit 1.8.1
# terminado              0.17.1
# threadpoolctl          3.1.0
# tifffile               2021.11.2
# tinycss2               1.2.1
# tomli                  2.0.1
# torch                  1.12.1+cu116
# torchaudio             0.12.1+cu116
# torchvision            0.13.1+cu116
# tornado                6.2
# tqdm                   4.67.1
# traceback2             1.4.0
# traitlets              5.9.0
# typing_extensions      4.7.1
# unittest2              1.1.0
# uri-template           1.3.0
# urllib3                2.0.7
# wcwidth                0.2.14
# webcolors              1.13
# webencodings           0.5.1
# websocket-client       1.6.1
# Werkzeug               3.1.3
# wheel                  0.46.1
# widgetsnbextension     4.0.14
# y-py                   0.6.2
# ypy-websocket          0.8.4
# zipp                   3.15.0

# %%
# !pip list
# Out:
# Package                Version
# ---------------------- ------------
# absl-py                2.3.1
# aiofiles               22.1.0
# aiosqlite              0.19.0
# anyio                  3.7.1
# argon2-cffi            23.1.0
# argon2-cffi-bindings   21.2.0
# arrow                  1.2.3
# attrs                  24.2.0
# Babel                  2.14.0
# backcall               0.2.0
# batchgenerators        0.20.1
# beautifulsoup4         4.14.2
# bleach                 6.0.0
# cached-property        1.5.2
# cachetools             4.2.4
# certifi                2025.8.3
# cffi                   1.15.1
# charset-normalizer     3.4.3
# comm                   0.1.4
# cycler                 0.11.0
# debugpy                1.7.0
# decorator              5.1.1
# defusedxml             0.7.1
# entrypoints            0.4
# exceptiongroup         1.3.0
# fastjsonschema         2.21.2
# fonttools              4.38.0
# fqdn                   1.5.1
# future                 1.0.0
# google-auth            1.35.0
# google-auth-oauthlib   0.4.6
# grpcio                 1.48.2
# idna                   3.10
# imageio                2.5.0
# importlib-metadata     6.7.0
# importlib-resources    5.12.0
# ipykernel              6.16.2
# ipython                7.34.0
# ipython-genutils       0.2.0
# ipywidgets             8.1.7
# isoduration            20.11.0
# jedi                   0.19.2
# Jinja2                 3.1.6
# joblib                 1.3.2
# json5                  0.9.16
# jsonpointer            3.0.0
# jsonschema             4.17.3
# jupyter                1.1.1
# jupyter_client         7.4.9
# jupyter-console        6.6.3
# jupyter_core           4.12.0
# jupyter-events         0.6.3
# jupyter-server         1.24.0
# jupyter_server_fileid  0.9.3
# jupyter_server_ydoc    0.8.0
# jupyter-ydoc           0.2.5
# jupyterlab             3.6.8
# jupyterlab-pygments    0.2.2
# jupyterlab_server      2.24.0
# jupyterlab_widgets     3.0.15
# kiwisolver             1.4.5
# linecache2             1.0.0
# Markdown               3.9
# MarkupSafe             2.1.5
# matplotlib             3.5.3
# matplotlib-inline      0.1.6
# mistune                3.0.2
# nbclassic              1.2.0
# nbclient               0.7.4
# nbconvert              7.6.0
# nbformat               5.8.0
# nest-asyncio           1.6.0
# networkx               2.6.3
# ninja                  1.11.1.4
# nms-extension          0.0.0
# notebook               6.5.7
# notebook_shim          0.2.4
# numpy                  1.21.6
# oauthlib               3.3.1
# packaging              24.0
# pandas                 0.25.3
# pandocfilters          1.5.1
# parso                  0.8.5
# pexpect                4.9.0
# pickleshare            0.7.5
# Pillow                 7.0.0
# pip                    24.0
# pkgutil_resolve_name   1.3.10
# prometheus-client      0.17.1
# prompt_toolkit         3.0.48
# protobuf               6.32.1
# psutil                 7.1.0
# ptyprocess             0.7.0
# pyasn1                 0.6.1
# pyasn1_modules         0.4.2
# pycparser              2.21
# Pygments               2.17.2
# pyparsing              3.1.4
# pyrsistent             0.19.3
# python-dateutil        2.9.0.post0
# python-json-logger     3.0.1
# pytz                   2025.2
# PyWavelets             1.3.0
# PyYAML                 6.0.1
# pyzmq                  26.2.1
# requests               2.31.0
# requests-oauthlib      2.0.0
# rfc3339-validator      0.1.4
# rfc3986-validator      0.1.1
# rsa                    4.9.1
# scikit-image           0.18.3
# scikit-learn           1.0.2
# scipy                  1.7.3
# Send2Trash             1.8.3
# setuptools             68.0.0
# SimpleITK              1.2.4
# six                    1.17.0
# sniffio                1.3.1
# soupsieve              2.4.1
# tensorboard            2.2.0
# tensorboard-plugin-wit 1.8.1
# terminado              0.17.1
# threadpoolctl          3.1.0
# tifffile               2021.11.2
# tinycss2               1.2.1
# tomli                  2.0.1
# torch                  1.12.1+cu116
# torchaudio             0.12.1+cu116
# torchvision            0.13.1+cu116
# tornado                6.2
# tqdm                   4.67.1
# traceback2             1.4.0
# traitlets              5.9.0
# typing_extensions      4.7.1
# unittest2              1.1.0
# uri-template           1.3.0
# urllib3                2.0.7
# wcwidth                0.2.14
# webcolors              1.13
# webencodings           0.5.1
# websocket-client       1.6.1
# Werkzeug               3.1.3
# wheel                  0.46.1
# widgetsnbextension     4.0.14
# y-py                   0.6.2
# ypy-websocket          0.8.4
# zipp                   3.15.0

# %%
import torch
print(torch.__version__)
print(torch.version.cuda)
print(torch.cuda.is_available())
# Out:
# 1.12.1+cu116
# 11.6
# True

# %%
import torch
import torch.nn as nn
import torch.optim as optim

# 1. Check if GPU is available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)

# 2. Create dummy dataset (simple linear relation)
X = torch.randn(1000, 10).to(device)
y = torch.randn(1000, 1).to(device)

# 3. Define a tiny neural network
class SimpleNet(nn.Module):
    def __init__(self):
        super(SimpleNet, self).__init__()
        self.fc = nn.Linear(10, 1)

    def forward(self, x):
        return self.fc(x)

model = SimpleNet().to(device)

# 4. Loss and optimizer
criterion = nn.MSELoss()
optimizer = optim.SGD(model.parameters(), lr=0.01)

# 5. Training loop
for epoch in range(5):
    optimizer.zero_grad()
    outputs = model(X)
    loss = criterion(outputs, y)
    loss.backward()
    optimizer.step()
    print(f"Epoch [{epoch+1}/5], Loss: {loss.item():.4f}")

print("Training finished ✅")
# Out:
# Using device: cuda
# Epoch [1/5], Loss: 1.3387
# Epoch [2/5], Loss: 1.3258
# Epoch [3/5], Loss: 1.3135
# Epoch [4/5], Loss: 1.3017
# Epoch [5/5], Loss: 1.2904
# Training finished ✅
